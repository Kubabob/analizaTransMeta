# %% [markdown]
# #### Importowanie bibliotek

# %%
import pandas as pd
import seaborn as sns

import matplotlib.pyplot as plt

sns.set_style("darkgrid")

# %% [markdown]
# #### Wczytanie zbioru danych

# %%
df = pd.read_csv("Metabolomics_Final_clean_filtered.csv")

# %%
df.head()
# Out:
#      Name  Group  Metabolite1  Metabolite2  Metabolite3  Metabolite4  \
# 0  Blank1  Blank     0.296615    -0.710610    -2.901369    -0.650964
# 1  Blank2  Blank     0.624823    -0.824232    -3.064853    -0.643874
# 2  Blank3  Blank     0.543235    -0.847690    -2.977496    -0.628404
# 3  Blank4  Blank     0.406324    -0.895123    -3.013405    -0.649124
# 4  Blank5  Blank     0.494052    -0.826526    -3.102939    -0.646171
#
#    Metabolite5  Metabolite6  Metabolite7  Metabolite8  ...  Metabolite490  \
# 0    -2.043614    -2.597074    -0.693295    -1.712962  ...      -1.574612
# 1    -1.971934    -2.661216    -0.747467    -1.695005  ...      -1.698349
# 2    -2.038637    -2.617125    -0.782076    -1.727032  ...      -1.649857
# 3    -2.140211    -2.636845    -0.823426    -1.806523  ...      -1.654070
# 4    -2.129675    -2.663344    -0.844134    -1.783338  ...      -1.665414
#
#    Metabolite491  Metabolite492  Metabolite493  Metabolite494  Metabolite495  \
# ...

# %% [markdown]
# #### Filtrowanie próbek kontroli jakości ze zbioru danych

# %%
df = df[df['Group'] == 'QC']

# %%
df.head()
# Out:
#    Name Group  Metabolite1  Metabolite2  Metabolite3  Metabolite4  \
# 6   QC1    QC    -0.113787    -0.025823     0.336567    -0.356011
# 7   QC2    QC    -0.110645    -0.038333     0.291136    -0.368409
# 8   QC3    QC    -0.054817     0.021213     0.242480    -0.364435
# 9   QC4    QC    -0.062339     0.103875     0.165753    -0.343093
# 10  QC5    QC    -0.086306     0.014897     0.288291    -0.364756
#
#     Metabolite5  Metabolite6  Metabolite7  Metabolite8  ...  Metabolite490  \
# 6      0.715838     0.260039    -0.129049     0.436005  ...       0.547380
# 7      0.543956     0.241081    -0.130231     0.277480  ...       0.691778
# 8      0.567932     0.235948    -0.199729     0.298620  ...       0.505837
# 9      0.557338     0.199098    -0.200478     0.332105  ...       0.574271
# 10     0.427892     0.212360    -0.172693     0.285546  ...       0.551708
#
#     Metabolite491  Metabolite492  Metabolite493  Metabolite494  Metabolite495  \
# ...

# %%
df.shape
# Out:
# (18, 501)

# %% [markdown]
# #### Obliczenie macierzy korelacji dla obiektów

# %%
# Drop non-numeric columns (Name and Group) and transpose the DataFrame
numeric_df = df.drop(['Name', 'Group'], axis=1)
correlation_matrix = numeric_df.T.corr()

# Optionally, display the correlation matrix
print("Correlation matrix shape:", correlation_matrix.shape)
correlation_matrix
# Out:
# Correlation matrix shape: (18, 18)
#           6         7         8         9         10        11        12  \
# 6   1.000000  0.877373  0.842711  0.831616  0.815782  0.909810  0.875686
# 7   0.877373  1.000000  0.796053  0.796905  0.785021  0.876740  0.855870
# 8   0.842711  0.796053  1.000000  0.733700  0.726021  0.814004  0.807301
# 9   0.831616  0.796905  0.733700  1.000000  0.702131  0.802303  0.769369
# 10  0.815782  0.785021  0.726021  0.702131  1.000000  0.776027  0.781883
# 11  0.909810  0.876740  0.814004  0.802303  0.776027  1.000000  0.859256
# 12  0.875686  0.855870  0.807301  0.769369  0.781883  0.859256  1.000000
# 13  0.944172  0.912412  0.851835  0.841935  0.823511  0.924281  0.903224
# 14  0.881808  0.844073  0.794795  0.772860  0.795150  0.849060  0.823153
# 15  0.899475  0.882655  0.805881  0.803589  0.806937  0.887437  0.836510
# 16  0.795131  0.762963  0.708693  0.701096  0.693454  0.781392  0.699576
# ...

# %%
correlation_matrix.describe()
# Out:
#               6          7          8          9          10         11  \
# count  18.000000  18.000000  18.000000  18.000000  18.000000  18.000000
# mean    0.816259   0.793088   0.743034   0.733930   0.728950   0.798620
# std     0.151150   0.159327   0.153049   0.153884   0.154352   0.154161
# min     0.305006   0.246569   0.252691   0.227953   0.220179   0.280765
# 25%     0.800294   0.768477   0.713025   0.701355   0.695623   0.777368
# 50%     0.855577   0.831917   0.793115   0.767710   0.777187   0.830250
# 75%     0.881660   0.871523   0.806946   0.800953   0.798915   0.872369
# max     1.000000   1.000000   1.000000   1.000000   1.000000   1.000000
#
#               12         13         14         15         16         17  \
# count  18.000000  18.000000  18.000000  18.000000  18.000000  18.000000
# mean    0.780625   0.826680   0.769603   0.792327   0.697708   0.766308
# std     0.138170   0.150189   0.156491   0.158130   0.159346   0.158281
# ...

# %% [markdown]
# #### Heatmapa macierzy korelacji

# %%
# Create a heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, 
            cmap='coolwarm', 
            center=0,
            annot=True,
            fmt='.2f',
            square=True)

plt.title('Correlation Matrix Heatmap')
plt.tight_layout()
plt.show()

# %% [markdown]
# Wysokie wartości korelacji między blankami wskazuje na poprawne przygotowanie aparatury do pomiarów
