# %% [markdown]
# <ul>
# <li>Jak się zachowuje blank</li>
#
# <li>Oszacować jaka jest odpowiedź sprzętu dla blanku w stosunku do średniej uzyskanych dla danych</li>
#
# <li>Jak zachowują się próbki quality control</li>
# </ul>

# %% [markdown]
# <h4>Import bibliotek</h4>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("darkgrid")

# %% [markdown]
# <h4>Wczytanie plików do analizy</h4>

# %%
qual_df1 = pd.read_excel("Metabolomika_Quality1.xlsx")
qual_df2 = pd.read_excel("Metabolomika_Quality2.xlsx")

# %% [markdown]
# <h4>Wyświetlenie części danych, wymiarów i krótko statystyk</h4>

# %%
qual_df1.head()
# Out:
#       Id       Group            M1            M2            M3            M4  \
# 0  F_HM1  F_Mutacja2  5.957279e+10  3.010289e+09  2.419360e+09  3.475658e+10
# 1  F_HM2  F_Mutacja2  3.261696e+10  1.202132e+09  1.028235e+09  1.985418e+10
# 2  F_HM3  F_Mutacja2  4.710931e+10  4.235189e+09  3.731590e+09  2.954711e+10
# 3  F_HM4  F_Mutacja2  4.105237e+10  5.480769e+10  6.266317e+10  2.751340e+10
# 4  F_HM5  F_Mutacja2  8.245476e+10  4.795234e+09  3.809418e+09  5.674860e+10
#
#              M5            M6            M7            M8  ...         M1190  \
# 0  1.095557e+10  1.820461e+10  4.352209e+10  4.040102e+10  ...  1.174422e+07
# 1  5.097178e+09  8.471569e+09  2.088800e+10  4.951979e+09  ...  7.158440e+06
# 2  1.389437e+10  1.848030e+10  2.629877e+10  3.185078e+10  ...  3.795373e+06
# 3  5.997451e+10  4.372237e+10  2.382849e+10  4.136071e+10  ...  3.287727e+07
# 4  1.153197e+10  1.989166e+10  3.385781e+10  4.839285e+10  ...  7.356279e+06
#
# ...

# %%
qual_df1.shape
# Out:
# (220, 1201)

# %%
qual_df1['Group'].value_counts()
# Out:
# Group
# Blank         38
# F_Kontrola    29
# M_Kontrola    28
# F_Mutacja1    28
# M_Mutacja1    27
# F_Mutacja2    27
# QC            22
# M_Mutacja2    21
# Name: count, dtype: int64

# %%
qual_df2.head()
# Out:
#   Unnamed: 0        Unnamed: 1        Unnamed: 2          Unnamed: 3  \
# 0        NaN            Blank1            Blank2              Blank3
# 1         M1   96050301.189067   91071913.798473    130188374.515884
# 2         M2  5190022905.80748  2427643936.48469  13622766045.204599
# 3         M3   37227156.982608   30727357.671339      41898495.55181
# 4         M4   49812971.982919   17933984.303862      9379937.976367
#
#          Unnamed: 4        Unnamed: 5          Unnamed: 6        Unnamed: 7  \
# 0            Blank4            Blank5              Blank6            Blank7
# 1  144525722.751977  107318018.292966    266197041.995283  110669570.744356
# 2  4785712597.17914  4248665290.76787  31901453283.248901   22958908.704539
# 3   47658756.073795   37787753.868623     48359048.381559   44060174.034634
# 4  5683682578.80977   17901062.023144    151598337.788689    3736066.816465
#
#          Unnamed: 8          Unnamed: 9  ... Unnamed: 1190 Unnamed: 1191  \
# ...

# %%
qual_df2.shape
# Out:
# (1348, 1200)

# %%
qual_df2.iloc[0,:].unique()
# Out:
# array([nan, 'Blank1', 'Blank2', 'Blank3', 'Blank4', 'Blank5', 'Blank6',
#        'Blank7', 'Blank8', 'Blank9', 'Blank10', 'QC1', 'QC2', 'QC3',
#        'QC4', 'QC5', 'QC6', 'QC7', 'QC8', 'QC9', 'QC10', 'QC11', 'QC12',
#        'QC13', 'QC14', 'QC15', 'QC16', 'QC17', 'QC18', 'F_HT1', 'F_HT2',
#        'F_HT3', 'F_HT4', 'F_HT5', 'F_HT6', 'F_Kontrola1', 'F_Kontrola2',
#        'F_Kontrola3', 'F_Kontrola4', 'F_Kontrola5', 'F_HM1', 'F_HM2',
#        'F_HM3', 'F_HM4', 'F_HM5', 'F_HM6', 'F_HT7', 'F_HT8', 'F_HT9',
#        'F_HT10', 'F_HT11', 'F_HT12', 'F_HT13', 'F_HT14', 'F_HT15',
#        'F_Kontrola6', 'F_Kontrola7', 'F_Kontrola8', 'F_Kontrola9',
#        'F_Kontrola10', 'F_Kontrola11', 'F_Kontrola12', 'F_HM7', 'F_HM8',
#        'F_HM9', 'F_HM10', 'F_HM11', 'F_HM12', 'F_HM13', 'F_HM14',
#        'F_HT16', 'F_HT17', 'F_HT18', 'F_HT19', 'F_HT20', 'F_HT21',
#        'F_HT22', 'F_Kontrola13', 'F_Kontrola14', 'F_Kontrola15',
# ...

# %%
qual_df2.iloc[0,:].nunique()
# Out:
# 146

# %% [markdown]
# <h4>Macierz korelacji kowariancji</h4>

# %%
qual_df1.iloc[:,2:].corr()
# Out:
#              M1        M2        M3        M4        M5        M6        M7  \
# M1     1.000000  0.064955  0.059622  0.964600  0.288996  0.481302  0.868063
# M2     0.064955  1.000000  0.974089  0.189647  0.840113  0.693290  0.063379
# M3     0.059622  0.974089  1.000000  0.185153  0.860124  0.735458  0.056283
# M4     0.964600  0.189647  0.185153  1.000000  0.397843  0.580156  0.786062
# M5     0.288996  0.840113  0.860124  0.397843  1.000000  0.917842  0.286178
# ...         ...       ...       ...       ...       ...       ...       ...
# M1195  0.473454  0.297831  0.287200  0.549995  0.360664  0.410401  0.332292
# M1196  0.384737  0.418121  0.373203  0.482387  0.421909  0.390552  0.169272
# M1197  0.745881  0.255527  0.235441  0.778297  0.382363  0.479465  0.655085
# M1198  0.525018  0.166263  0.156105  0.578145  0.267737  0.359879  0.295595
# M1199  0.648818  0.339239  0.338538  0.679153  0.459331  0.500282  0.604252
#
# ...

# %% [markdown]
# Widać, że niektóre wartości są wysoko skorelowane

# %%
qual_df2
# Out:
#         Unnamed: 0        Unnamed: 1          Unnamed: 2          Unnamed: 3  \
# 0              NaN            Blank1              Blank2              Blank3
# 1               M1   96050301.189067     91071913.798473    130188374.515884
# 2               M2  5190022905.80748    2427643936.48469  13622766045.204599
# 3               M3   37227156.982608     30727357.671339      41898495.55181
# 4               M4   49812971.982919     17933984.303862      9379937.976367
# ...            ...               ...                 ...                 ...
# 1343  M_Kontrola13  559565528.757725  44558982677.888702    4957863078.23143
# 1344  M_Kontrola14  935276573.118361  51308306646.874802    4619694118.58622
# 1345  M_Kontrola15  619220488.642601  49904584548.010902    3242918197.52239
# 1346  M_Kontrola16  166814096.867582  39042682551.636703    1194294766.02071
# 1347  M_Kontrola17  1797891761.49983  79370582121.382294     820335082.75137
#
# ...
